# %%
using MLDatasets
using ImageCore
using LinearAlgebra
using PyPlot
using Random
using Statistics
using Printf
using JLD2, FileIO
using ProgressMeter
using TestImages
using ImageTransformations

# %%
@load "JLDs/Correlation10.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,linewidth=1.5,color="#ff7f0e",linestyle ="dashed", marker="o",label = "HNN-Corr")
@load "JLDs/Projection10.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,color="blue",linestyle ="dashed", marker=">",label = "HNN-Proj")
@load "JLDs/S110.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,color="red",linestyle ="solid", marker="s",label = "HNN-S1")
@load "JLDs/S210.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,linewidth=1,color="#2ca02c",linestyle ="solid", marker="s",label = "HNN-S2")
title("Hopfield Neural Networks for P=10 and N=200")
xlabel("Noise Level")
ylabel("Success Rate")
#legend(bbox_to_anchor=[1,1],loc=2,borderaxespad=0)
legend()
grid()
savefig("JLDs/All_HNN_10.eps")
savefig("JLDs/All_HNN_10.pdf")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
@load "JLDs/Correlation20.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,linewidth=1.5,color="#ff7f0e",linestyle ="dashed", marker="o",label = "HNN-Corr")
@load "JLDs/Projection20.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,color="blue",linestyle ="dashed", marker=">",label = "HNN-Proj")
@load "JLDs/S120.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,color="red",linestyle ="solid", marker="s",label = "HNN-S1")
@load "JLDs/S220.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,linewidth=1,color="#2ca02c",linestyle ="solid", marker="s",label = "HNN-S2")
title("Hopfield Neural Networks for P=20 and N=200")
xlabel("Noise Level")
ylabel("Success Rate")
#legend(bbox_to_anchor=[1,1],loc=2,borderaxespad=0)
legend()
grid()
savefig("JLDs/All_HNN_20.eps")
savefig("JLDs/All_HNN_20.pdf")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
@load "JLDs/Correlation40.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,linewidth=1.5,color="#ff7f0e",linestyle ="dashed", marker="o",label = "HNN-Corr")
@load "JLDs/Projection40.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,color="blue",linestyle ="dashed", marker=">",label = "HNN-Proj")
@load "JLDs/S140.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,color="red",linestyle ="solid", marker="s",label = "HNN-S1")
@load "JLDs/S240.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,linewidth=1,color="#2ca02c",linestyle ="solid", marker="s",label = "HNN-S2")
title("Hopfield Neural Networks for P=40 and N=200")
xlabel("Noise Level")
ylabel("Success Rate")
#legend(bbox_to_anchor=[1,1],loc=2,borderaxespad=0)
legend()
grid()
savefig("JLDs/All_HNN_40.eps")
savefig("JLDs/All_HNN_40.pdf")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
@load "JLDs/Correlation60.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,linewidth=1.5,color="#ff7f0e",linestyle ="dashed", marker="o",label = "HNN-Corr")
@load "JLDs/Projection60.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,color="blue",linestyle ="dashed", marker=">",label = "HNN-Proj")
@load "JLDs/S160.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,color="red",linestyle ="solid", marker="s",label = "HNN-S1")
@load "JLDs/S260.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,linewidth=1,color="#2ca02c",linestyle ="solid", marker="s",label = "HNN-S2")
title("Hopfield Neural Networks for P=60 and N=100")
xlabel("Noise Level")
ylabel("Success Rate")
#legend(bbox_to_anchor=[1,1],loc=2,borderaxespad=0)
legend()
grid()
savefig("JLDs/All_HNN_60.eps")
savefig("JLDs/All_HNN_60.pdf")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
