# %%
using MLDatasets
using ImageCore
using LinearAlgebra
using PyPlot
using Random
using Statistics
using Printf
using JLD2, FileIO
using ProgressMeter
#using TestImages
#using ImageTransformations

# %%
rcParams = PyPlot.PyDict(PyPlot.matplotlib."rcParams")
font0 = Dict(
        "font.size" => 18,
        "axes.labelweight" => "bold",
        "axes.labelsize" => 16,
        "xtick.labelsize" => 16,
        "ytick.labelsize" => 16,
        "legend.fontsize" => 13,
)
merge!(rcParams, font0)

@load "JLDs/S110.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,linewidth=1.5,color="red",linestyle ="dashed", marker="o",markersize = 10,
             markeredgewidth=1.5, markeredgecolor=(0,0,0),label = "1st Order Storkey")

@load "JLDs/S210.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,color="#2ca02c",linestyle ="dashed", marker=">",markersize = 10,markeredgewidth=1.5, markeredgecolor=(0,0,0),label = "2nd Order Storkey")

@load "JLDs/Correlation10.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,color="orange",linestyle ="solid", marker="s",markersize = 10,markeredgewidth=1.5, markeredgecolor=(0,0,0),label = "Hebb learning")

@load "JLDs/Projection10.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,linewidth=1,color="blue",linestyle ="solid",markersize = 10,markeredgewidth=1.5, markeredgecolor=(0,0,0), marker="d",label = "Projection rule")

#title("Hopfield Neural Networks for P=40 and N=200")
xlabel("Noise Probability")
ylabel("Success Rate")

legend()
grid()
savefig("JLDs/All_HNN_10.eps")
savefig("JLDs/All_HNN_10.pdf")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
rcParams = PyPlot.PyDict(PyPlot.matplotlib."rcParams")
font0 = Dict(
        "font.size" => 18,
        "axes.labelweight" => "bold",
        "axes.labelsize" => 16,
        "xtick.labelsize" => 16,
        "ytick.labelsize" => 16,
        "legend.fontsize" => 13,
)
merge!(rcParams, font0)

@load "JLDs/S120.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,linewidth=1.5,color="red",linestyle ="dashed", marker="o",markersize = 10,
             markeredgewidth=1.5, markeredgecolor=(0,0,0),markevery=2,label = "1st Order Storkey")

@load "JLDs/S220.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,color="#2ca02c",linestyle ="dashed", marker=">",markersize = 10,markeredgewidth=1.5, markeredgecolor=(0,0,0),markevery=3,label = "2nd Order Storkey")

@load "JLDs/Correlation20.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,color="orange",linestyle ="solid", marker="s",markersize = 10,markeredgewidth=1.5, markeredgecolor=(0,0,0),markevery=3,label = "Hebb learning")

@load "JLDs/Projection20.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,linewidth=1,color="blue",linestyle ="solid",markersize = 10,markeredgewidth=1.5, markeredgecolor=(0,0,0),markevery=3, marker="d",label = "Projection rule")

xlabel("Noise Probability")
ylabel("Success Rate")

legend()
grid()
savefig("JLDs/All_HNN_20.eps")
savefig("JLDs/All_HNN_20.pdf")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
rcParams = PyPlot.PyDict(PyPlot.matplotlib."rcParams")
font0 = Dict(
        "font.size" => 18,
        "axes.labelweight" => "bold",
        "axes.labelsize" => 16,
        "xtick.labelsize" => 16,
        "ytick.labelsize" => 16,
        "legend.fontsize" => 13,
)
merge!(rcParams, font0)

@load "JLDs/S140.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,linewidth=1.5,color="red",linestyle ="dashed", marker="o",markersize = 10,
             markeredgewidth=1.5, markeredgecolor=(0,0,0),label = "1st Order Storkey")

@load "JLDs/S240.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,color="#2ca02c",linestyle ="dashed", marker=">",markersize = 10,markeredgewidth=1.5, markeredgecolor=(0,0,0),label = "2nd Order Storkey")

@load "JLDs/Correlation40.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,color="orange",linestyle ="solid", marker="s",markersize = 10,markeredgewidth=1.5, markeredgecolor=(0,0,0),label = "Hebb learning")

@load "JLDs/Projection40.jld2"
plot(NoiseValues,Success_0[1,:]/Nsim,linewidth=1,color="blue",linestyle ="solid",markersize = 10,markeredgewidth=1.5, markeredgecolor=(0,0,0), marker="d",label = "Projection rule")

xlabel("Noise Probability")
ylabel("Success Rate")

legend()
grid()
savefig("JLDs/All_HNN_40.eps")
savefig("JLDs/All_HNN_40.pdf")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
